# %%
# !pip install pillow
# !pip install opencv-python
# Out:
# ...
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      -------- ------------------------------- 0.5/2.5 MB 10.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.0/2.5 MB 11.0 MB/s eta 0:00:01
#      ------------------------- -------------- 1.6/2.5 MB 11.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.1/2.5 MB 11.3 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 10.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#      ---------------------------------------- 0.4/38.2 MB 13.5 MB/s eta 0:00:03
#      - -------------------------------------- 1.0/38.2 MB 12.2 MB/s eta 0:00:04
#      - -------------------------------------- 1.5/38.2 MB 11.7 MB/s eta 0:00:04
#      -- ------------------------------------- 2.0/38.2 MB 11.7 MB/s eta 0:00:04
#      -- ------------------------------------- 2.6/38.2 MB 11.6 MB/s eta 0:00:04
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/7.6 MB 14.2 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.0/7.6 MB 12.6 MB/s eta 0:00:01
#      -------- ------------------------------- 1.5/7.6 MB 12.1 MB/s eta 0:00:01
#      ---------- ----------------------------- 2.1/7.6 MB 12.0 MB/s eta 0:00:01
#      ------------- -------------------------- 2.6/7.6 MB 12.0 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.2/7.6 MB 11.9 MB/s eta 0:00:01
#      ------------------- -------------------- 3.7/7.6 MB 11.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 4.3/7.6 MB 11.8 MB/s eta 0:00:01
#      ------------------------- -------------- 4.8/7.6 MB 11.9 MB/s eta 0:00:01
#      ---------------------------- ----------- 5.4/7.6 MB 11.8 MB/s eta 0:00:01
#      ------------------------------ --------- 5.9/7.6 MB 11.8 MB/s eta 0:00:01
# ...

# %%
import os
#from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
os.chdir(r'E:\CCA-Si\2021_5_23_BRCA1 Ola and AZD\BRCA1 nodrug')

# %%
image = cv2.imread('seq6406.tif', cv2.IMREAD_GRAYSCALE)

# %%
# Display the image
plt.imshow(image)
plt.show()

# %%
# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')
plt.show()

# %%
# Find contours in the threshold image
contours, hierarchy = cv2.findContours(threshold, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Draw the contours on the original image
image_contours = image.copy()
cv2.drawContours(image_contours, contours, -1, (0, 0, 255), 2)
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  3,   3,   1],
#         ...,
#         [ 44,  18,   2],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        ...,
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  3,   1,   1],
#         ...,
#         [ 22,   9,   1],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
# ...

# %%
# Display the image with contours
plt.imshow(cv2.cvtColor(image_contours, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Find contours in the threshold image
contours, hierarchy = cv2.findContours(threshold, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
print(f"Number of cells in the image: {num_cells}")
# Out:
# Number of cells in the image: 2651

# %%
# Load the image as grayscale
image = cv2.imread('seq6406.tif', cv2.IMREAD_GRAYSCALE)

# Apply a threshold to the grayscale image
_, binary_image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY)

# Display the binary image
cv2.imshow('Binary Image', binary_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
